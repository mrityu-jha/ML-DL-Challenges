# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
ROOT_DIR = 'M:\My Files\Mrityunjay Jha\Programming\Competition\Credit Risk Prediction - Univ.AI'
INPUT = os.path.join( ROOT_DIR, 'input' )
CSV_PATH = os.path.join( INPUT, 'csvs' )
TRAIN_CSV_PATH = os.path.join(CSV_PATH, 'train.csv')
TEST_CSV_PATH = os.path.join(CSV_PATH, 'test.csv')

# %%
train = pd.read_csv( TRAIN_CSV_PATH )
test = pd.read_csv( TEST_CSV_PATH )

# %%
train['state'].unique()
# Out:
# array(['Madhya_Pradesh', 'Maharashtra', 'Kerala', 'Odisha', 'Tamil_Nadu',
#        'Gujarat', 'Rajasthan', 'Telangana', 'Bihar', 'Andhra_Pradesh',
#        'West_Bengal', 'Haryana', 'Puducherry', 'Karnataka',
#        'Uttar_Pradesh', 'Himachal_Pradesh', 'Punjab', 'Tripura',
#        'Uttarakhand', 'Jharkhand', 'Mizoram', 'Assam',
#        'Jammu_and_Kashmir', 'Delhi', 'Chhattisgarh', 'Chandigarh',
#        'Uttar_Pradesh[5]', 'Manipur', 'Sikkim'], dtype=object)

# %%
test.head()
# Out:
#    id   income  age  experience  married house_ownership car_ownership  \
# 0   1  7393090   59          19   single          rented            no
# 1   2  1215004   25           5   single          rented            no
# 2   3  8901342   50          12   single          rented            no
# 3   4  1944421   49           9  married          rented           yes
# 4   5    13429   25          18   single          rented           yes
#
#     profession        city        state  current_job_years  \
# 0    Geologist       Malda  West Bengal                  4
# 1  Firefighter       Jalna  Maharashtra                  5
# 2       Lawyer       Thane  Maharashtra                  9
# 3      Analyst       Latur  Maharashtra                  3
# 4     Comedian  Berhampore  West Bengal                 13
#
#    current_house_years
# 0                   13
# 1                   10
# 2                   14
# 3                   12
# 4                   11

# %%
train.isnull().sum()
# Out:
# Id                     0
# income                 0
# age                    0
# experience             0
# married                0
# house_ownership        0
# car_ownership          0
# profession             0
# city                   0
# state                  0
# current_job_years      0
# current_house_years    0
# risk_flag              0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# id                     0
# income                 0
# age                    0
# experience             0
# married                0
# house_ownership        0
# car_ownership          0
# profession             0
# city                   0
# state                  0
# current_job_years      0
# current_house_years    0
# dtype: int64

# %%
train.dtypes
# Out:
# Id                      int64
# income                  int64
# age                     int64
# experience              int64
# married                object
# house_ownership        object
# car_ownership          object
# profession             object
# city                   object
# state                  object
# current_job_years       int64
# current_house_years     int64
# risk_flag               int64
# dtype: object

# %%
test.dtypes
# Out:
# id                      int64
# income                  int64
# age                     int64
# experience              int64
# married                object
# house_ownership        object
# car_ownership          object
# profession             object
# city                   object
# state                  object
# current_job_years       int64
# current_house_years     int64
# dtype: object

# %% [markdown]
# ## Looking Into Object Variables ##

# %%
train_obj = train.select_dtypes( include = ['object'] )
test_obj = test.select_dtypes( include = ['object'] )

# %%
train_obj.head()
# Out:
#    married house_ownership car_ownership           profession  \
# 0   single          rented            no  Mechanical_engineer
# 1   single          rented            no   Software_Developer
# 2  married          rented            no     Technical_writer
# 3   single          rented           yes   Software_Developer
# 4   single          rented            no        Civil_servant
#
#                   city           state
# 0                 Rewa  Madhya_Pradesh
# 1             Parbhani     Maharashtra
# 2            Alappuzha          Kerala
# 3          Bhubaneswar          Odisha
# 4  Tiruchirappalli[10]      Tamil_Nadu

# %%
test_obj.head()
# Out:
#    married house_ownership car_ownership   profession        city        state
# 0   single          rented            no    Geologist       Malda  West Bengal
# 1   single          rented            no  Firefighter       Jalna  Maharashtra
# 2   single          rented            no       Lawyer       Thane  Maharashtra
# 3  married          rented           yes      Analyst       Latur  Maharashtra
# 4   single          rented           yes     Comedian  Berhampore  West Bengal

# %%
train_obj['married'].unique()
# Out:
# array(['single', 'married'], dtype=object)

# %%
train_obj['house_ownership'].unique()
# Out:
# array(['rented', 'norent_noown', 'owned'], dtype=object)

# %%
train_obj['car_ownership'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
train_obj['profession'].unique()
# Out:
# array(['Mechanical_engineer', 'Software_Developer', 'Technical_writer',
#        'Civil_servant', 'Librarian', 'Economist', 'Flight_attendant',
#        'Architect', 'Designer', 'Physician', 'Financial_Analyst',
#        'Air_traffic_controller', 'Politician', 'Police_officer', 'Artist',
#        'Surveyor', 'Design_Engineer', 'Chemical_engineer',
#        'Hotel_Manager', 'Dentist', 'Comedian', 'Biomedical_Engineer',
#        'Graphic_Designer', 'Computer_hardware_engineer',
#        'Petroleum_Engineer', 'Secretary', 'Computer_operator',
#        'Chartered_Accountant', 'Technician', 'Microbiologist',
#        'Fashion_Designer', 'Aviator', 'Psychologist', 'Magistrate',
#        'Lawyer', 'Firefighter', 'Engineer', 'Official', 'Analyst',
#        'Geologist', 'Drafter', 'Statistician', 'Web_designer',
#        'Consultant', 'Chef', 'Army_officer', 'Surgeon', 'Scientist',
#        'Civil_engineer', 'Industrial_Engineer', 'Technology_specialist'],
#       dtype=object)

# %%
train_obj['city'].unique()
# Out:
# array(['Rewa', 'Parbhani', 'Alappuzha', 'Bhubaneswar',
#        'Tiruchirappalli[10]', 'Jalgaon', 'Tiruppur', 'Jamnagar',
#        'Kota[6]', 'Karimnagar', 'Hajipur[31]', 'Adoni', 'Erode[17]',
#        'Kollam', 'Madurai', 'Anantapuram[24]', 'Kamarhati', 'Bhusawal',
#        'Sirsa', 'Amaravati', 'Secunderabad', 'Ahmedabad', 'Ajmer',
#        'Ongole', 'Miryalaguda', 'Ambattur', 'Indore', 'Pondicherry',
#        'Shimoga', 'Chennai', 'Gulbarga', 'Khammam', 'Saharanpur',
#        'Gopalpur', 'Amravati', 'Udupi', 'Howrah', 'Aurangabad[39]',
#        'Hospet', 'Shimla', 'Khandwa', 'Bidhannagar', 'Bellary', 'Danapur',
#        'Purnia[26]', 'Bijapur', 'Patiala', 'Malda', 'Sagar', 'Durgapur',
#        'Junagadh', 'Singrauli', 'Agartala', 'Thanjavur', 'Hindupur',
#        'Naihati', 'North_Dumdum', 'Panchkula', 'Anantapur', 'Serampore',
#        'Bathinda', 'Nadiad', 'Kanpur', 'Haridwar', 'Berhampur',
#        'Jamshedpur', 'Hyderabad', 'Bidar', 'Kottayam', 'Solapur',
# ...

# %%
train_obj['state'].unique()
# Out:
# array(['Madhya_Pradesh', 'Maharashtra', 'Kerala', 'Odisha', 'Tamil_Nadu',
#        'Gujarat', 'Rajasthan', 'Telangana', 'Bihar', 'Andhra_Pradesh',
#        'West_Bengal', 'Haryana', 'Puducherry', 'Karnataka',
#        'Uttar_Pradesh', 'Himachal_Pradesh', 'Punjab', 'Tripura',
#        'Uttarakhand', 'Jharkhand', 'Mizoram', 'Assam',
#        'Jammu_and_Kashmir', 'Delhi', 'Chhattisgarh', 'Chandigarh',
#        'Uttar_Pradesh[5]', 'Manipur', 'Sikkim'], dtype=object)

# %%
train.drop( ['Id'], axis = 1, inplace = True )

# %%
train.head()
# Out:
#     income  age  experience  married house_ownership car_ownership  \
# 0  1303835   23           3   single          rented            no
# 1  7574516   40          10   single          rented            no
# 2  3991815   66           4  married          rented            no
# 3  6256451   41           2   single          rented           yes
# 4  5768871   47          11   single          rented            no
#
#             profession                 city           state  \
# 0  Mechanical_engineer                 Rewa  Madhya_Pradesh
# 1   Software_Developer             Parbhani     Maharashtra
# 2     Technical_writer            Alappuzha          Kerala
# 3   Software_Developer          Bhubaneswar          Odisha
# 4        Civil_servant  Tiruchirappalli[10]      Tamil_Nadu
#
#    current_job_years  current_house_years  risk_flag
# 0                  3                   13          0
# 1                  9                   13          0
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252000 entries, 0 to 251999
# Data columns (total 12 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   income               252000 non-null  int64
#  1   age                  252000 non-null  int64
#  2   experience           252000 non-null  int64
#  3   married              252000 non-null  object
#  4   house_ownership      252000 non-null  object
#  5   car_ownership        252000 non-null  object
#  6   profession           252000 non-null  object
#  7   city                 252000 non-null  object
#  8   state                252000 non-null  object
#  9   current_job_years    252000 non-null  int64
#  10  current_house_years  252000 non-null  int64
#  11  risk_flag            252000 non-null  int64
# dtypes: int64(6), object(6)
# memory usage: 23.1+ MB

# %%
train.describe()
# Out:
#            income        age  experience  current_job_years  \
# count  252000.000 252000.000  252000.000         252000.000
# mean  4997116.665     49.954      10.084              6.334
# std   2878311.014     17.064       6.003              3.647
# min     10310.000     21.000       0.000              0.000
# 25%   2503015.000     35.000       5.000              3.000
# 50%   5000694.500     50.000      10.000              6.000
# 75%   7477502.000     65.000      15.000              9.000
# max   9999938.000     79.000      20.000             14.000
#
#        current_house_years  risk_flag
# count           252000.000 252000.000
# mean                11.998      0.123
# std                  1.399      0.328
# min                 10.000      0.000
# 25%                 11.000      0.000
# 50%                 12.000      0.000
# 75%                 13.000      0.000
# max                 14.000      1.000

# %%
train_num = train.select_dtypes( include = ['int64'] )

# %%
sns.heatmap( train_num.corr(), annot = True )
# Out:
# <AxesSubplot:>

# %%
plt.figure( figsize = ( 20, 10 ))
plt.xticks( size = 17, rotation = 'vertical' )
sns.countplot( x = 'state', hue = 'risk_flag', data = train )
# Out:
# <AxesSubplot:xlabel='state', ylabel='count'>

# %%
train.groupby( by = ['state', 'risk_flag' ] ).size()
# Out:
# state              risk_flag
# Andhra_Pradesh     0            22362
#                    1             2935
# Assam              0             6132
#                    1              930
# Bihar              0            17197
#                    1             2583
# Chandigarh         0              595
#                    1               61
# Chhattisgarh       0             3323
#                    1              511
# Delhi              0             4916
#                    1              574
# Gujarat            0            10065
#                    1             1343
# Haryana            0             6910
#                    1              980
# Himachal_Pradesh   0              722
#                    1              111
# Jammu_and_Kashmir  0             1497
#                    1              283
# Jharkhand          0             7770
#                    1             1195
# Karnataka          0            10666
#                    1             1189
# ...

# %%
train.groupby( ['risk_flag'] ).size()
# Out:
# risk_flag
# 0    221004
# 1     30996
# dtype: int64

# %%
train[['profession', 'risk_flag']].groupby( by = ['profession'] ).mean().plot.bar( figsize = (20, 10))
# Out:
# <AxesSubplot:xlabel='profession'>

# %%
plt.figure( figsize = ( 20, 10 ))
plt.xticks( size = 17, rotation = 'vertical' )
sns.countplot( x = 'profession', hue = 'risk_flag', data = train )
# Out:
# <AxesSubplot:xlabel='profession', ylabel='count'>

# %%
train[['income', 'profession']].groupby( by = ['profession'] ).mean().plot.bar( figsize = ( 20, 10 ) )
# Out:
# <AxesSubplot:xlabel='profession'>

# %%
train[['income', 'risk_flag', 'profession']].groupby( by = ['profession', 'risk_flag'] ).mean()
# Out:
#                                       income
# profession             risk_flag
# Air_traffic_controller 0         5006005.720
#                        1         4654549.545
# Analyst                0         4890349.482
#                        1         4921895.340
# Architect              0         4954688.374
# ...                                      ...
# Technician             1         5450802.840
# Technology_specialist  0         4994423.304
#                        1         4886673.311
# Web_designer           0         4833278.313
#                        1         5381373.742
#
# [102 rows x 1 columns]

# %%
sns.displot( data = train, x = 'age', bins = 5, hue = 'risk_flag', color = 'r', kde = True )

# %%
train[['car_ownership', 'risk_flag']].groupby( by = ['car_ownership'] ).size()
# Out:
# car_ownership
# no     176000
# yes     76000
# dtype: int64

# %%
train.columns
# Out:
# Index(['income', 'age', 'experience', 'married', 'house_ownership',
#        'car_ownership', 'profession', 'city', 'state', 'current_job_years',
#        'current_house_years', 'risk_flag'],
#       dtype='object')

# %%
sns.pairplot( train, hue = 'risk_flag' )

# %%
sns.heatmap( train.drop( ['experience'], axis = 1 ).corr(), annot = True )
# Out:
# <AxesSubplot:>

# %%
train[['married', 'risk_flag']].groupby( by = ['married'] ).mean()
# Out:
#          risk_flag
# married
# married      0.102
# single       0.125

# %%
train[['profession', 'income']].groupby( by = ['profession'], as_index = True ).mean().sort_values( by = 'income', ascending = False )
# Out:
#                                 income
# profession
# Petroleum_Engineer         5443309.827
# Psychologist               5357795.262
# Designer                   5336802.230
# Scientist                  5282710.423
# Surgeon                    5235358.713
# Comedian                   5199538.529
# Chemical_engineer          5189804.995
# Mechanical_engineer        5175032.069
# Artist                     5164765.182
# Financial_Analyst          5145752.515
# Consultant                 5138435.813
# Lawyer                     5128131.462
# Computer_operator          5112549.849
# Surveyor                   5112352.284
# Secretary                  5102879.894
# Army_officer               5094472.726
# Aviator                    5074103.520
# Fashion_Designer           5070883.084
# Industrial_Engineer        5060502.183
# Firefighter                5046134.009
# Microbiologist             5035357.999
# Statistician               5028648.270
# Librarian                  5007589.705
# ...

# %%
train['prev_job_exp'] = train['experience'] - train['current_job_years']
train.drop( ['experience'], axis = 1, inplace = True )

# %%
train.head()
# Out:
#    Id   income  age  experience  married house_ownership car_ownership  \
# 0   1  1303835   23           3   single          rented            no
# 1   2  7574516   40          10   single          rented            no
# 2   3  3991815   66           4  married          rented            no
# 3   4  6256451   41           2   single          rented           yes
# 4   5  5768871   47          11   single          rented            no
#
#             profession                 city           state  \
# 0  Mechanical_engineer                 Rewa  Madhya_Pradesh
# 1   Software_Developer             Parbhani     Maharashtra
# 2     Technical_writer            Alappuzha          Kerala
# 3   Software_Developer          Bhubaneswar          Odisha
# 4        Civil_servant  Tiruchirappalli[10]      Tamil_Nadu
#
#    current_job_years  current_house_years  risk_flag
# 0                  3                   13          0
# 1                  9                   13          0
# ...

# %%
train[['income', 'state']].groupby( by = ['state'] ).mean().sort_values( by = ['income'], ascending = False )
# Out:
# <AxesSubplot:ylabel='state'>

# %%
train[['risk_flag', 'state']].groupby( by = ['state'] ).mean().sort_values( by = ['risk_flag'], ascending = False )
# Out:
#                    risk_flag
# state
# Manipur                0.216
# Tripura                0.168
# Kerala                 0.167
# Jammu_and_Kashmir      0.159
# Madhya_Pradesh         0.154
# Odisha                 0.143
# Rajasthan              0.141
# Jharkhand              0.133
# Chhattisgarh           0.133
# Himachal_Pradesh       0.133
# Assam                  0.132
# Bihar                  0.131
# Uttar_Pradesh[5]       0.131
# Telangana              0.130
# West_Bengal            0.128
# Haryana                0.124
# Gujarat                0.118
# Uttar_Pradesh          0.118
# Puducherry             0.117
# Andhra_Pradesh         0.116
# Maharashtra            0.113
# Mizoram                0.111
# Delhi                  0.105
# Tamil_Nadu             0.103
# Karnataka              0.100
# Chandigarh             0.093
# Punjab                 0.090
# Uttarakhand            0.071
# Sikkim                 0.046

# %%
train[['income', 'city']].groupby( by = ['city'] ).mean().sort_values( by = ['income'], ascending = True )
# Out:
#                       income
# city
# Nashik           3314763.366
# Mathura          3369112.854
# Bhiwani          3537748.044
# Hapur            3789153.608
# Tezpur           3797353.132
# ...                      ...
# Bhiwandi         6276792.707
# Rajpur_Sonarpur  6350836.607
# Sultan_Pur_Majra 6433848.182
# Secunderabad     6517802.116
# Munger           6678175.285
#
# [317 rows x 1 columns]

# %%
train[['risk_flag', 'city']].groupby( by = ['city'] ).mean().sort_values( by = ['risk_flag'], ascending = True )
# Out:
#                   risk_flag
# city
# Gandhinagar           0.026
# Dehradun              0.026
# Sultan_Pur_Majra      0.034
# Bijapur               0.035
# Bangalore             0.037
# ...                     ...
# Raiganj               0.240
# Kochi                 0.253
# Bettiah[33]           0.267
# Gwalior               0.273
# Bhubaneswar           0.326
#
# [317 rows x 1 columns]

# %%
def add_noise(series, noise_level):
    return series * (1 + noise_level * np.random.randn(len(series)))

def target_encode(trn_series=None, 
                  tst_series=None, 
                  target=None, 
                  min_samples_leaf=1, 
                  smoothing=1,
                  noise_level=0):
    """
    Smoothing is computed like in the following paper by Daniele Micci-Barreca
    https://kaggle2.blob.core.windows.net/forum-message-attachments/225952/7441/high%20cardinality%20categoricals.pdf
    trn_series : training categorical feature as a pd.Series
    tst_series : test categorical feature as a pd.Series
    target : target data as a pd.Series
    min_samples_leaf (int) : minimum samples to take category average into account
    smoothing (int) : smoothing effect to balance categorical average vs prior  
    """ 
    assert len(trn_series) == len(target)
    assert trn_series.name == tst_series.name
    temp = pd.concat([trn_series, target], axis=1)
    # Compute target mean 
    averages = temp.groupby(by=trn_series.name)[target.name].agg(["mean", "count"])
    # Compute smoothing
    smoothing = 1 / (1 + np.exp(-(averages["count"] - min_samples_leaf) / smoothing))
    # Apply average function to all target data
    prior = target.mean()
    # The bigger the count the less full_avg is taken into account
    averages[target.name] = prior * (1 - smoothing) + averages["mean"] * smoothing
    averages.drop(["mean", "count"], axis=1, inplace=True)
    # Apply averages to trn and tst series
    ft_trn_series = pd.merge(
        trn_series.to_frame(trn_series.name),
        averages.reset_index().rename(columns={'index': target.name, target.name: 'average'}),
        on=trn_series.name,
        how='left')['average'].rename(trn_series.name + '_mean').fillna(prior)
    # pd.merge does not keep the index so restore it
    ft_trn_series.index = trn_series.index 
    ft_tst_series = pd.merge(
        tst_series.to_frame(tst_series.name),
        averages.reset_index().rename(columns={'index': target.name, target.name: 'average'}),
        on=tst_series.name,
        how='left')['average'].rename(trn_series.name + '_mean').fillna(prior)
    # pd.merge does not keep the index so restore it
    ft_tst_series.index = tst_series.index
    return add_noise(ft_trn_series, noise_level), add_noise(ft_tst_series, noise_level)

# %%
trn, sub = target_encode(train["city"], 
                         test["city"], 
                         target=train.risk_flag, 
                         min_samples_leaf=100,
                         smoothing=10,
                         noise_level=0.01)

# %%
def save_csv( df ):
    df = df.assign( city =df1['E'] )
